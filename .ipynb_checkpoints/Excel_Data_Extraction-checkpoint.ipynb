# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_excel('F:\\Invoice_Validation\\Walmart Sales JAN18 to JAN19.xls')

# %%
df2 = pd.read_excel('F:\\Invoice_Validation\\MAIN-RANSTAD-PETER.xls')

# %%
df3 = pd.merge(df1, df2, on=['EmpName','To date'], how='outer')
df3
# Out:
#         Invoice No  Billed Qty Unit     Rate  \
# 0      972787818.0       112.0    H     23.0
# 1      971335616.0       149.0    H     65.0
# 2      971335638.0       176.0    H     65.0
# 3      971283566.0        40.0    H     65.0
# 4      971284078.0        40.0    H     65.0
# 5      971285051.0        32.0    H     65.0
# 6      971286479.0        32.0    H     65.0
# 7      971286660.0        40.0    H     65.0
# 8      971297100.0        40.0    H     65.0
# 9      971300026.0        40.0    H     65.0
# 10     971304055.0        32.0    H     65.0
# 11     971306238.0        40.0    H     65.0
# 12     971307574.0        40.0    H     65.0
# 13     971317594.0        40.0    H     65.0
# 14     971364957.0        40.0    H     65.0
# 15     971320346.0        32.0    H     65.0
# 16     971364943.0        32.0    H     65.0
# 17     971333821.0        40.0    H     65.0
# 18     971333478.0        40.0    H     65.0
# 19     971336987.0        40.0    H     65.0
# ...

# %%
df3.to_excel('F:\\Invoice_Validation\\Filtered_Data.xls')

# %%
#df1['Status'] = np.where(df1['Material Description'].isin (df2['WIPRO NAME']) & df1['To date'].isin (df2['Week Ending Date']), 'Found', 'Not Found')
#df1['Amount'] = np.where(df1['Material Description'].isin (df2['WIPRO NAME']) & df1['To date'].isin (df2['Week Ending Date']), df2['Voucher Amount'], '')

# %%
#df1.loc[df1['Material Description'].isin (df2['WIPRO NAME']) & df1['To date'].isin (df2['Week Ending Date']), 'status']='Found'
#df1.to_excel('F:\\Invoice_Validation\\Filtered_Data.xls')

# %%
np.random.seed(0)
left = pd.DataFrame({'key': ['A', 'B', 'C', 'D'], 'value': np.random.randn(4)})    
right = pd.DataFrame({'key': ['B', 'D', 'E', 'F'], 'value': np.random.randn(4)})

# %%
left
# Out:
#   key     value
# 0   A  1.764052
# 1   B  0.400157
# 2   C  0.978738
# 3   D  2.240893

# %%
right
# Out:
#   key     value
# 0   B  1.867558
# 1   D -0.977278
# 2   E  0.950088
# 3   F -0.151357

# %%
pd.merge(left, right, on='key', how='outer')
# Out:
#   key   value_x   value_y
# 0   A  1.764052       NaN
# 1   B  0.400157  1.867558
# 2   C  0.978738       NaN
# 3   D  2.240893 -0.977278
# 4   E       NaN  0.950088
# 5   F       NaN -0.151357
